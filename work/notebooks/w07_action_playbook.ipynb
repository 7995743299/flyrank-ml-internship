# %% [markdown]
# <a href="https://colab.research.google.com/github/7995743299/flyrank-ml-internship/blob/main/work/notebooks/w07_action_playbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-10 — Content Action Playbook
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %%
import pandas as pd

actions = pd.DataFrame({
    "Priority":[1,2,3,4],
    "Action":[
        "Refresh outdated content",
        "Improve keyword optimization",
        "Update internal links",
        "Monitor page performance"
    ],
    "Reason Code":[
        "Content Decay",
        "Low Keyword Coverage",
        "Weak Internal Linking",
        "Performance Monitoring"
    ]
})

print(actions)

print("\nObservation:")
print("Refreshing outdated content is the highest priority because content decay has the greatest impact on SEO performance.")
# Out:
#    Priority                        Action             Reason Code
# 0         1      Refresh outdated content           Content Decay
# 1         2  Improve keyword optimization    Low Keyword Coverage
# 2         3         Update internal links   Weak Internal Linking
# 3         4      Monitor page performance  Performance Monitoring
#
# Observation:
# Refreshing outdated content is the highest priority because content decay has the greatest impact on SEO performance.

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
Intended Use

This playbook helps content teams prioritize website improvements using machine learning predictions. It is intended as a decision-support tool and not an automated publishing system.

 Limits

- Predictions are based only on the available dataset.
- Results should not be generalized without additional validation.
- Human review is required before implementing recommendations.
"""))
# Out:
# ## Intended Use
#
# This playbook helps content teams prioritize website improvements using machine learning predictions. It is intended as a decision-support tool and not an automated publishing system.
#
# ## Limits
#
# - Predictions are based only on the available dataset.
# - Results should not be generalized without additional validation.
# - Human review is required before implementing recommendations.

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
 Human Review

Every recommendation should be reviewed by a content editor before publication.

 Do Not Automate

- Publishing new content
- Deleting pages
- Changing rankings manually
- Making business decisions without human approval
"""))
# Out:
#  Human Review
#
# Every recommendation should be reviewed by a content editor before publication.
#
#  Do Not Automate
#
# - Publishing new content
# - Deleting pages
# - Changing rankings manually
# - Making business decisions without human approval

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
Monitoring

Monitor model accuracy and website performance monthly.

Retrain the model when:

- New content patterns appear.
- Performance decreases significantly.
- New historical data becomes available.
"""))
# Out:
# Monitoring
#
# Monitor model accuracy and website performance monthly.
#
# Retrain the model when:
#
# - New content patterns appear.
# - Performance decreases significantly.
# - New historical data becomes available.

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %%
import os

os.makedirs("work/outputs", exist_ok=True)

actions.to_csv(
    "work/outputs/action_queue.csv",
    index=False
)

print("Export completed successfully.")
# Out:
# Export completed successfully.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
