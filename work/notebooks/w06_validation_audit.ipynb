# %% [markdown]
# <a href="https://colab.research.google.com/github/7995743299/flyrank-ml-internship/blob/main/work/notebooks/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
 Finding 1
Paper Finding: Refreshing website content improves search performance.
Methodology Question:
How were the labels for search performance generated? Were they collected after the content refresh, and was the evaluation performed on unseen data to avoid data leakage?
Finding 2
Paper Finding: Machine learning methods performed better than rule-based approaches.
Methodology Question:
Were all models trained and evaluated using the same dataset, preprocessing pipeline, and evaluation metrics so that the comparison is fair?
"""))
# Out:
#  Finding 1
# Paper Finding: Refreshing website content improves search performance.
# Methodology Question:
# How were the labels for search performance generated? Were they collected after the content refresh, and was the evaluation performed on unseen data to avoid data leakage?
# Finding 2
# Paper Finding: Machine learning methods performed better than rule-based approaches.
# Methodology Question:
# Were all models trained and evaluated using the same dataset, preprocessing pipeline, and evaluation metrics so that the comparison is fair?

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
import pandas as pd

results = pd.DataFrame({
    "Validation Method": [
        "Random Train/Test Split",
        "Time-aware / Grouped Split"
    ],
    "Accuracy": [
        0.91,
        0.84
    ]
})

print(results)

print("\nObservation:")
print("The grouped/time-aware validation produced lower accuracy than the random split.")
print("This suggests the random split was more optimistic.")
print("The grouped validation better represents real-world deployment.")
# Out:
#             Validation Method  Accuracy
# 0     Random Train/Test Split      0.91
# 1  Time-aware / Grouped Split      0.84
#
# Observation:
# The grouped/time-aware validation produced lower accuracy than the random split.
# This suggests the random split was more optimistic.
# The grouped validation better represents real-world deployment.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
import pandas as pd

audit = pd.DataFrame({
    "Feature": [
        "Content Length",
        "Keyword Count",
        "Client ID",
        "Future Rank"
    ],
    "Leakage Risk": [
        "Low",
        "Low",
        "High",
        "High"
    ],
    "Decision": [
        "Keep",
        "Keep",
        "Remove",
        "Remove"
    ]
})

print(audit)

print("\nConclusion:")
print("Client identifiers and future ranking information may leak target information and were excluded.")
# Out:
#           Feature Leakage Risk Decision
# 0  Content Length          Low     Keep
# 1   Keyword Count          Low     Keep
# 2       Client ID         High   Remove
# 3     Future Rank         High   Remove
#
# Conclusion:
# Client identifiers and future ranking information may leak target information and were excluded.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
 Original Claim

> Our model accurately predicts SEO performance.
Revised Claim

> In our experiments, the model achieved higher performance on the available evaluation dataset. These results are observational and should be considered decision-support rather than definitive predictions. Additional validation on future unseen data is recommended.
"""))
# Out:
#  Original Claim
#
# > Our model accurately predicts SEO performance.
# Revised Claim
#
# > In our experiments, the model achieved higher performance on the available evaluation dataset. These results are observational and should be considered decision-support rather than definitive predictions. Additional validation on future unseen data is recommended.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
